# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

mean = df['Age'].mean()
median = df['Age'].median()
std = df['Age'].std()
minimum = df['Age'].min()
maximum = df['Age'].max()
unique = df['Age'].unique()

print('Mean : ', mean)
print('Median : ', median)
print('Standard Deviation : ', std)
print('Minimum : ', minimum)
print('Maximum : ', maximum)
print('Unique Values : ', unique)
# Out:
# Mean :  29.69911764705882
# Median :  28.0
# Standard Deviation :  14.526497332334042
# Minimum :  0.42
# Maximum :  80.0
# Unique Values :  [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]
# Sorted Values :  803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64
# Sorted Values in Descending Order :       PassengerId  Survived  Pclass  \
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
sorted = df['Age'].sort_values()
print('Sorted Values :\n', sorted)
# Out:
# Sorted Values :
#  803    0.42
# 755    0.67
# 644    0.75
# 469    0.75
# 78     0.83
#        ...
# 859     NaN
# 863     NaN
# 868     NaN
# 878     NaN
# 888     NaN
# Name: Age, Length: 891, dtype: float64

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
sorted_asc = df.sort_values(by=["Age"], ascending=True).tail(10)
print('Sorted Values in Ascending Order : ', sorted_asc)
# Out:
# Sorted Values in Ascending Order :       PassengerId  Survived  Pclass  \
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 832                                Saad, Mr. Amin    male  NaN      0      0
# 837                           Sirota, Mr. Maurice    male  NaN      0      0
# 839                          Marechal, Mr. Pierre    male  NaN      0      0
# 846                      Sage, Mr. Douglas Bullen    male  NaN      8      2
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1      0
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
sorted_desc = df.sort_values(by=['Age'], ascending=False).tail(10)
print('Sorted Values in Descending Order : ', sorted_desc)
# Out:
# Sorted Values in Descending Order :       PassengerId  Survived  Pclass  \
# 832          833         0       3
# 837          838         0       3
# 839          840         1       1
# 846          847         0       3
# 849          850         1       1
# 859          860         0       3
# 863          864         0       3
# 868          869         0       3
# 878          879         0       3
# 888          889         0       3
#
#                                              Name     Sex  Age  SibSp  Parch  \
# 832                                Saad, Mr. Amin    male  NaN      0      0
# 837                           Sirota, Mr. Maurice    male  NaN      0      0
# 839                          Marechal, Mr. Pierre    male  NaN      0      0
# 846                      Sage, Mr. Douglas Bullen    male  NaN      8      2
# 849  Goldenberg, Mrs. Samuel L (Edwiga Grabowska)  female  NaN      1      0
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
condition = df['Sex'] == 'female'
df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
condition = df['Age'] < 40 # and df['Sex'] == 'female'
condition2 = df['Sex'] == 'female'
condition3 = df['Age'] > 35

df[condition & condition2 & condition3]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 25            26         1       3
# 61            62         1       1
# 325          326         1       1
# 327          328         1       2
# 357          358         0       2
# 387          388         1       2
# 503          504         0       3
# 518          519         1       2
# 540          541         1       1
# 558          559         1       1
# 559          560         1       3
# 577          578         1       1
# 581          582         1       1
# 610          611         0       3
# 716          717         1       1
# 763          764         1       1
# 835          836         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# ...

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
condition = (df['Age'] < 40) & (df['Sex'] == 'female')
# condition2 = df['Sex'] == 'female'> 35

df[condition]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### groupby()

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df[['Age', 'Name']].groupby(df['Sex']).max()
# Out:
#          Age                                          Name
# Sex
# female  63.0  de Messemaeker, Mrs. Guillaume Joseph (Emma)
# male    80.0                   van Melkebeke, Mr. Philemon

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
state_gender_res = df[['Sex','Survived']].groupby(['Sex']).agg(['count', 'min', 'max'])
state_gender_res
# Out:
#        Survived
#           count min max
# Sex
# female      314   0   1
# male        577   0   1

# %% [markdown]
# #### correlation
